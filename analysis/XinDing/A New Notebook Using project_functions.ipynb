# %%
import sys
import os

module_path = os.path.abspath(os.path.join(os.pardir, os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)
    
    
import project_functions

# %%
url_or_path_to_csv_file = 'http://data.insideairbnb.com/united-states/nc/asheville/2021-04-19/data/listings.csv.gz'
df = project_functions.load_and_process(url_or_path_to_csv_file)
df.head()
# Out:
#    host_id host_acceptance_rate host_response_rate  latitude  longitude  \
# 0   320564                  29%                88%  35.60670  -82.55563
# 1   746673                 100%               100%  35.57864  -82.59578
# 2   746673                 100%               100%  35.57864  -82.59578
# 3   746673                 100%               100%  35.57864  -82.59578
# 5  1029919                  43%               100%  35.61856  -82.55276
#
#            property_type        room_type  accommodates bathrooms  bedrooms  \
# 0       Entire apartment  Entire home/apt             2         1       1.0
# 1      Entire guesthouse  Entire home/apt             2         1       1.0
# 2  Private room in house     Private room             2       2.5       1.0
# 3  Shared room in hostel      Shared room             1       2.5       1.0
# 5     Entire guest suite  Entire home/apt             4         1       1.0
#
#    beds   price  review_scores_rating  reviews_per_month  superhost_flag  \
# 0   1.0   82.00                  90.0               0.76               0
# 1   1.0   90.00                  91.0               2.53               1
# 2   1.0   66.00                  90.0               0.57               1
# 3   6.0   33.00                  94.0               2.40               1
# 5   2.0  134.00                  97.0               0.49               0
#
#    host_identity_verified_flag
# 0                            1
# 1                            1
# 2                            1
# 3                            1
# 5                            1
